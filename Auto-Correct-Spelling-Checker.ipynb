# %% [markdown]
# <a href="https://colab.research.google.com/github/ssatendra790/Auto-Correct-Spelling-Checker/blob/main/Auto-Correct-Spelling-Checker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **AUTO CORRECT SPELLING CHECKER**\
# -\
# -\
# -
#
# **Identify a mispelled word**\
# A word is mispelled if it is not found in the vocabulary of the corpus of text the autocorrect system is working with\
# -\
# -\
# -\
# -

# %%
import re
import string
from collections import Counter
import numpy as np

# %%
def read_corpus(filename):
  with open(filename, "r") as file:
    lines = file.readlines()
    words = []

    for line in lines:
      words += re.findall(r'\w+',line.lower())

  return words

# %%
words = read_corpus("./bigf.txt")
print(f"There are {len(words)} total words in the corpus")
# Out:
# There are 4893393 total words in the corpus

# %%
vocabs = set(words)
print(f"There are {len(vocabs)} unique words in the vocabulary")
# Out:
# There are 186347 unique words in the vocabulary

# %%
word_counts = Counter(words)
print(word_counts["the"])
# Out:
# 274722

# %%
total_word_count = float(sum(word_counts.values()))
word_probas = {word: word_counts[word] / total_word_count for word in word_counts.keys()}

# %%
print(word_probas["the"])
# Out:
# 0.05614141353453524

# %%
def split(word):
  return [(word[:i], word[i:]) for i in range(len(word) + 1)]

# %%
print(split("satendra"))
# Out:
# [('', 'satendra'), ('s', 'atendra'), ('sa', 'tendra'), ('sat', 'endra'), ('sate', 'ndra'), ('saten', 'dra'), ('satend', 'ra'), ('satendr', 'a'), ('satendra', '')]

# %%
def delete(word):
  return [l + r[1:] for l,r in split(word) if r]

# %%
print(delete("satendra"))
# Out:
# ['atendra', 'stendra', 'saendra', 'satndra', 'satedra', 'satenra', 'satenda', 'satendr']

# %%
def swap(word):
  return [l + r[1] + r[0] + r[2:] for l,r in split(word) if len(r)>1]

# %%
print(swap("satendra"))
# Out:
# ['astendra', 'staendra', 'saetndra', 'satnedra', 'satednra', 'satenrda', 'satendar']

# %%
def replace(word):
  letters = string.ascii_lowercase
  return [l + c + r[1:] for l,r in split(word) if r for c in letters]

# %%
print(replace("satendra"))
# Out:
# ['aatendra', 'batendra', 'catendra', 'datendra', 'eatendra', 'fatendra', 'gatendra', 'hatendra', 'iatendra', 'jatendra', 'katendra', 'latendra', 'matendra', 'natendra', 'oatendra', 'patendra', 'qatendra', 'ratendra', 'satendra', 'tatendra', 'uatendra', 'vatendra', 'watendra', 'xatendra', 'yatendra', 'zatendra', 'satendra', 'sbtendra', 'sctendra', 'sdtendra', 'setendra', 'sftendra', 'sgtendra', 'shtendra', 'sitendra', 'sjtendra', 'sktendra', 'sltendra', 'smtendra', 'sntendra', 'sotendra', 'sptendra', 'sqtendra', 'srtendra', 'sstendra', 'sttendra', 'sutendra', 'svtendra', 'swtendra', 'sxtendra', 'sytendra', 'sztendra', 'saaendra', 'sabendra', 'sacendra', 'sadendra', 'saeendra', 'safendra', 'sagendra', 'sahendra', 'saiendra', 'sajendra', 'sakendra', 'salendra', 'samendra', 'sanendra', 'saoendra', 'sapendra', 'saqendra', 'sarendra', 'sasendra', 'satendra', 'sauendra', 'savendra', 'sawendra', 'saxendra', 'sayendra', 'sazendra', 'satandra', 'satbndra', 'satcndra', 'satdndra', 'satendra', 'satfndra', 'satgndra', 'sathndra', 'satindra', 'satjndra', 'satkndra', 'satlndra', 'satmndra', 'satnndra', 'satondra', 'satpndra', 'satqndra', 'satrndra', 'satsndra', 'sattndra', 'satundra', 'satvndra', 'satwndra', 'satxndra', 'satyndra', 'satzndra', 'sateadra', 'satebdra', 'satecdra', 'sateddra', 'sateedra', 'satefdra', 'sategdra', 'satehdra', 'sateidra', 'satejdra', 'satekdra', 'sateldra', 'satemdra', 'satendra', 'sateodra', 'satepdra', 'sateqdra', 'saterdra', 'satesdra', 'satetdra', 'sateudra', 'satevdra', 'satewdra', 'satexdra', 'sateydra', 'satezdra', 'satenara', 'satenbra', 'satencra', 'satendra', 'satenera', 'satenfra', 'satengra', 'satenhra', 'satenira', 'satenjra', 'satenkra', 'satenlra', 'satenmra', 'satennra', 'satenora', 'satenpra', 'satenqra', 'satenrra', 'satensra', 'satentra', 'satenura', 'satenvra', 'satenwra', 'satenxra', 'satenyra', 'satenzra', 'satendaa', 'satendba', 'satendca', 'satendda', 'satendea', 'satendfa', 'satendga', 'satendha', 'satendia', 'satendja', 'satendka', 'satendla', 'satendma', 'satendna', 'satendoa', 'satendpa', 'satendqa', 'satendra', 'satendsa', 'satendta', 'satendua', 'satendva', 'satendwa', 'satendxa', 'satendya', 'satendza', 'satendra', 'satendrb', 'satendrc', 'satendrd', 'satendre', 'satendrf', 'satendrg', 'satendrh', 'satendri', 'satendrj', 'satendrk', 'satendrl', 'satendrm', 'satendrn', 'satendro', 'satendrp', 'satendrq', 'satendrr', 'satendrs', 'satendrt', 'satendru', 'satendrv', 'satendrw', 'satendrx', 'satendry', 'satendrz']

# %%
def insert(word):
  letters = string.ascii_lowercase
  return [l+c+ r for l,r in split(word) for c in letters]

# %%
print(insert("satendra"))
# Out:
# ['asatendra', 'bsatendra', 'csatendra', 'dsatendra', 'esatendra', 'fsatendra', 'gsatendra', 'hsatendra', 'isatendra', 'jsatendra', 'ksatendra', 'lsatendra', 'msatendra', 'nsatendra', 'osatendra', 'psatendra', 'qsatendra', 'rsatendra', 'ssatendra', 'tsatendra', 'usatendra', 'vsatendra', 'wsatendra', 'xsatendra', 'ysatendra', 'zsatendra', 'saatendra', 'sbatendra', 'scatendra', 'sdatendra', 'seatendra', 'sfatendra', 'sgatendra', 'shatendra', 'siatendra', 'sjatendra', 'skatendra', 'slatendra', 'smatendra', 'snatendra', 'soatendra', 'spatendra', 'sqatendra', 'sratendra', 'ssatendra', 'statendra', 'suatendra', 'svatendra', 'swatendra', 'sxatendra', 'syatendra', 'szatendra', 'saatendra', 'sabtendra', 'sactendra', 'sadtendra', 'saetendra', 'saftendra', 'sagtendra', 'sahtendra', 'saitendra', 'sajtendra', 'saktendra', 'saltendra', 'samtendra', 'santendra', 'saotendra', 'saptendra', 'saqtendra', 'sartendra', 'sastendra', 'sattendra', 'sautendra', 'savtendra', 'sawtendra', 'saxtendra', 'saytendra', 'saztendra', 'sataendra', 'satbendra', 'satcendra', 'satdendra', 'sateendra', 'satfendra', 'satgendra', 'sathendra', 'satiendra', 'satjendra', 'satkendra', 'satlendra', 'satmendra', 'satnendra', 'satoendra', 'satpendra', 'satqendra', 'satrendra', 'satsendra', 'sattendra', 'satuendra', 'satvendra', 'satwendra', 'satxendra', 'satyendra', 'satzendra', 'sateandra', 'satebndra', 'satecndra', 'satedndra', 'sateendra', 'satefndra', 'sategndra', 'satehndra', 'sateindra', 'satejndra', 'satekndra', 'satelndra', 'satemndra', 'satenndra', 'sateondra', 'satepndra', 'sateqndra', 'saterndra', 'satesndra', 'satetndra', 'sateundra', 'satevndra', 'satewndra', 'satexndra', 'sateyndra', 'satezndra', 'satenadra', 'satenbdra', 'satencdra', 'satenddra', 'satenedra', 'satenfdra', 'satengdra', 'satenhdra', 'satenidra', 'satenjdra', 'satenkdra', 'satenldra', 'satenmdra', 'satenndra', 'satenodra', 'satenpdra', 'satenqdra', 'satenrdra', 'satensdra', 'satentdra', 'satenudra', 'satenvdra', 'satenwdra', 'satenxdra', 'satenydra', 'satenzdra', 'satendara', 'satendbra', 'satendcra', 'satenddra', 'satendera', 'satendfra', 'satendgra', 'satendhra', 'satendira', 'satendjra', 'satendkra', 'satendlra', 'satendmra', 'satendnra', 'satendora', 'satendpra', 'satendqra', 'satendrra', 'satendsra', 'satendtra', 'satendura', 'satendvra', 'satendwra', 'satendxra', 'satendyra', 'satendzra', 'satendraa', 'satendrba', 'satendrca', 'satendrda', 'satendrea', 'satendrfa', 'satendrga', 'satendrha', 'satendria', 'satendrja', 'satendrka', 'satendrla', 'satendrma', 'satendrna', 'satendroa', 'satendrpa', 'satendrqa', 'satendrra', 'satendrsa', 'satendrta', 'satendrua', 'satendrva', 'satendrwa', 'satendrxa', 'satendrya', 'satendrza', 'satendraa', 'satendrab', 'satendrac', 'satendrad', 'satendrae', 'satendraf', 'satendrag', 'satendrah', 'satendrai', 'satendraj', 'satendrak', 'satendral', 'satendram', 'satendran', 'satendrao', 'satendrap', 'satendraq', 'satendrar', 'satendras', 'satendrat', 'satendrau', 'satendrav', 'satendraw', 'satendrax', 'satendray', 'satendraz']

# %%
def level_one_edits(word):
  return set(delete(word) + swap(word) + replace(word) + insert(word))

# %%
print(level_one_edits("satendra"))
# Out:
# {'satenbdra', 'satfndra', 'satfendra', 'satendba', 'saetendra', 'satendaa', 'szatendra', 'sqatendra', 'satendna', 'wsatendra', 'satkendra', 'spatendra', 'sbatendra', 'sateddra', 'satendua', 'saitendra', 'satendira', 'sagtendra', 'satendrpa', 'yatendra', 'sateydra', 'satendga', 'satenfra', 'satemndra', 'natendra', 'satexndra', 'satehndra', 'satendrja', 'satenbra', 'satednra', 'osatendra', 'satenqdra', 'satendrd', 'satkndra', 'sajendra', 'satgndra', 'satendxa', 'satendrya', 'satenpra', 'satenhra', 'satjendra', 'ysatendra', 'satendrc', 'satendraj', 'ratendra', 'satundra', 'satenrdra', 'satendza', 'satendrda', 'esatendra', 'satendrsa', 'satendraf', 'satenara', 'sateandra', 'satenmdra', 'satnndra', 'qatendra', 'satpendra', 'sarendra', 'satendea', 'vsatendra', 'satuendra', 'satevdra', 'satentra', 'satendwra', 'zsatendra', 'smtendra', 'satendja', 'saiendra', 'satendras', 'satepndra', 'satenpdra', 'sateundra', 'dsatendra', 'sftendra', 'msatendra', 'usatendra', 'staendra', 'satendrq', 'satenvra', 'satendya', 'satendraz', 'hatendra', 'satebndra', 'satendva', 'satendrah', 'satendrna', 'satendrav', 'satendroa', 'saeendra', 'satendrw', 'saqtendra', 'sytendra', 'satendri', 'bsatendra', 'satendsa', 'satengra', 'sadendra', 'sdtendra', 'satenira', 'satendraw', 'satenddra', 'uatendra', 'satendrax', 'sfatendra', 'satendrva', 'satendrat', 'satoendra', 'fatendra', 'satendora', 'satedndra', 'jatendra', 'satetdra', 'scatendra', 'satendura', 'atendra', 'saoendra', 'sateudra', 'satendrb', 'sawtendra', 'sategndra', 'sahendra', 'satbendra', 'sttendra', 'satenzdra', 'satendara', 'satendral', 'xatendra', 'sptendra', 'sawendra', 'savtendra', 'qsatendra', 'sahtendra', 'satenjra', 'sakendra', 'satendfa', 'satennra', 'satendrab', 'satendrza', 'satsendra', 'satendrga', 'snatendra', 'sxatendra', 'satenidra', 'satendrxa', 'sktendra', 'ssatendra', 'satendrh', 'satenydra', 'satendsra', 'satenyra', 'sbtendra', 'gatendra', 'satentdra', 'satendrg', 'safendra', 'satendrwa', 'satmndra', 'sitendra', 'satendrag', 'saterdra', 'saxendra', 'satendgra', 'satzndra', 'satandra', 'satendria', 'satjndra', 'setendra', 'sgtendra', 'satdendra', 'gsatendra', 'skatendra', 'sagendra', 'satendray', 'satesdra', 'jsatendra', 'satexdra', 'sstendra', 'satendbra', 'satendmra', 'csatendra', 'satekdra', 'satenxdra', 'satcendra', 'satendla', 'zatendra', 'saftendra', 'satenrra', 'satendta', 'satendry', 'saotendra', 'satendrra', 'samendra', 'satendia', 'sateldra', 'satenera', 'satendvra', 'satendqa', 'satendrt', 'smatendra', 'satendtra', 'satetndra', 'satendoa', 'satxndra', 'fsatendra', 'xsatendra', 'satenlra', 'satenkdra', 'satenodra', 'santendra', 'satelndra', 'sjatendra', 'sqtendra', 'satlndra', 'satendrfa', 'savendra', 'satezndra', 'sdatendra', 'sactendra', 'datendra', 'satenadra', 'satendrka', 'sotendra', 'suatendra', 'satvndra', 'satendpa', 'katendra', 'aatendra', 'satendrz', 'satendkra', 'satendrca', 'saqendra', 'sltendra', 'satyndra', 'satendrla', 'satendrf', 'satendrp', 'soatendra', 'sattndra', 'sateondra', 'sasendra', 'satpndra', 'sateidra', 'lsatendra', 'satqndra', 'satbndra', 'samtendra', 'sxtendra', 'sapendra', 'satendrm', 'satlendra', 'satendlra', 'satengdra', 'svatendra', 'satendfra', 'sateindra', 'sutendra', 'satendrad', 'satejdra', 'satendnra', 'satwendra', 'satendrma', 'satendrqa', 'sgatendra', 'satenwdra', 'satendran', 'satendrr', 'satendrao', 'rsatendra', 'satewdra', 'asatendra', 'satendrba', 'satendrae', 'srtendra', 'sratendra', 'sateqdra', 'saptendra', 'satecdra', 'satendrv', 'satendrak', 'satensdra', 'sateadra', 'satepdra', 'sntendra', 'saktendra', 'satdndra', 'satgendra', 'shatendra', 'satevndra', 'sateendra', 'satenedra', 'satenura', 'batendra', 'satxendra', 'satencdra', 'satecndra', 'satendrau', 'syatendra', 'latendra', 'satendera', 'salendra', 'satenhdra', 'satwndra', 'satendrar', 'satnedra', 'satendjra', 'sateedra', 'satenra', 'sartendra', 'satendka', 'satendxra', 'satendrs', 'satehdra', 'sztendra', 'satzendra', 'tatendra', 'satenda', 'satendr', 'satmendra', 'satefdra ...

# %% [markdown]
# **level_one_edits** checks for one error in one word.

# %%
def level_two_edits(word):
  return set(e2 for e1 in level_one_edits(word) for e2 in level_one_edits(e1))

# %% [markdown]
# **level_two_edits** checks for two errors in one word.

# %%
print(level_two_edits("satendra"))
# Out:
# {'qactendra', 'sartyndra', 'saktendrv', 'satenpras', 'satdndro', 'uatnndra', 'satenwka', 'toatendra', 'swterdra', 'yatengra', 'sathndrg', 'satendrmea', 'sactendrh', 'satkndora', 'rsyatendra', 'saxtendrak', 'jsatecdra', 'psatevndra', 'sbaitendra', 'sathesdra', 'satenbdoa', 'satrnfra', 'snaoendra', 'sabendrta', 'saeendry', 'gatesndra', 'ratendoa', 'yatendhra', 'sjtendr', 'sgtenpdra', 'satehndkra', 'satenbara', 'satgpndra', 'vaeendra', 'satendrlba', 'satenmna', 'sytendrf', 'sooatendra', 'ectendra', 'satyqendra', 'uszatendra', 'shrendra', 'sarenzdra', 'setendnra', 'xagendra', 'esvatendra', 'satenmrn', 'sateqndrwa', 'sxtenmdra', 'osatendrav', 'batmndra', 'szatecndra', 'skatevdra', 'satdezdra', 'sgatenbdra', 'staendcra', 'satenkrf', 'stendraq', 'satendrqoa', 'ratendra', 'satiendura', 'sbatendrai', 'srtendrz', 'savtendrk', 'safendna', 'eadendra', 'satiekdra', 'satennjdra', 'sarexdra', 'szaendra', 'natendrab', 'satevdla', 'zsatendora', 'psatendrba', 'jsatendras', 'satendrop', 'satendocra', 'asteendra', 'zatendkra', 'sgtendxra', 'saytendqa', 'ratenzra', 'satepnudra', 'watendpa', 'santenlra', 'siaqtendra', 'sdtbendra', 'satceidra', 'nsatetdra', 'uatenidra', 'sauindra', 'sntendrma', 'suteqdra', 'sajtendrah', 'nsatesdra', 'bsatnendra', 'osatemdra', 'sltqndra', 'saeenudra', 'uatrendra', 'ysatendrta', 'satzewdra', 'satenvdhra', 'sbatendora', 'sateondrau', 'saitendcra', 'sytendrab', 'saatendrap', 'zsatendpra', 'szatdndra', 'xsatdendra', 'sxatekndra', 'satendarza', 'datsendra', 'satanydra', 'satenmru', 'satendrwsa', 'sadendraj', 'satendlhra', 'satqnudra', 'sjtendrpa', 'saftendgra', 'saaendrwa', 'satendoka', 'sgtendaa', 'sariendra', 'satdenbra', 'staendra', 'swatendara', 'sdatendrd', 'udsatendra', 'satebndra', 'isatensra', 'yatkendra', 'satdenqra', 'smterdra', 'savtxendra', 'duatendra', 'sraetendra', 'satefdrpa', 'hsaiendra', 'jautendra', 'sateedraz', 'xsaterndra', 'skatenedra', 'saoehdra', 'sactencra', 'savtejdra', 'sawthendra', 'sotqendra', 'sateiddra', 'satendwo', 'sgstendra', 'satendradd', 'gsatendraf', 'siatenqra', 'iatengdra', 'satendrqo', 'shtqndra', 'swttndra', 'mxtendra', 'satendyna', 'satfegdra', 'zsxatendra', 'ratendrl', 'satinmra', 'jsatepdra', 'satiendraq', 'satbndrav', 'sadendza', 'soatendrn', 'sateldrha', 'xactendra', 'satesdga', 'satymndra', 'satbendrd', 'saitendrau', 'hsatgndra', 'statendla', 'saltenndra', 'ysatyndra', 'satenderaf', 'latendri', 'sanenxra', 'satfendria', 'satendnya', 'sawendrk', 'sttenora', 'sitendba', 'satenyba', 'samendrg', 'satezndrwa', 'satendrlan', 'sateinera', 'satdndea', 'isatenfra', 'satenydrua', 'satkendrt', 'sateepdra', 'qsatendraz', 'fatencra', 'satezndma', 'santentra', 'savtenyra', 'satelnzra', 'satendrqav', 'sstendrag', 'saowndra', 'saotendrs', 'satjepdra', 'satenwdrl', 'sualendra', 'savendxa', 'sateydrra', 'esatendrs', 'sjatdndra', 'satexhdra', 'sdatendrax', 'satepdpa', 'satenjmdra', 'fsatendda', 'sateendrt', 'snktendra', 'sgtendrb', 'saatendrd', 'satecdrau', 'saqctendra', 'sstendru', 'satunrra', 'satendraep', 'satenjrf', 'satqenara', 'svtenkra', 'siatendbra', 'saptenzra', 'saperdra', 'zsatejndra', 'satendiv', 'qsatendrs', 'xsatenira', 'satennrac', 'snarendra', 'hsatemdra', 'sateqdrax', 'satuendrax', 'sagtebndra', 'skytendra', 'satendpz', 'sateudcra', 'satenudmra', 'satezdaa', 'sahtendraf', 'usatendrap', 'satendray', 'tsatetndra', 'gatendea', 'satendore', 'satgendrsa', 'satyndea', 'satebdza', 'jqtendra', 'satsndlra', 'satnedrja', 'catendrat', 'tsateddra', 'satdebndra', 'sagemndra', 'sateqdraf', 'xaoendra', 'laendra', 'satwlndra', 'sautendrg', 'satenzdura', 'saikndra', 'sbtecndra', 'staendrg', 'sdanendra', 'csatmendra', 'jatefdra', 'sanendrna', 'sqtegdra', 'satpndaa', 'sathnqdra', 'satendrdia', 'scktendra', 'satdndrap', 'satenrdrta', 'satenysra', 'skatenfra', 'satenddzra', 'ksatenhra', 'hatevndra', 'satsjndra', 'satenrdk', 'sametdra', 'sqatejndra', 'vsatendrh', 'sayedra', 'satenpdrac', 'sautendrax', 'kqsatendra', 'msaktendra', 'aatenjra', 'sateddrwa', 'sdatendrau', 'sasendwa', 'satoehdra', 'satendj ...

# %%
def correct_spelling(word, vocabulary, word_probabilities):
  if word in vocabulary:
    print(f"{word} is Correctly Spelled")
    return
  suggestion = level_one_edits(word) or level_two_edits(word) or [word]
  best_guesses = [w for w in suggestion if w in vocabulary]
  return [(w, word_probabilities[w]) for w in best_guesses]

# %% [markdown]
# -\
# -\
# -\
# -\
# -\
# -
#
#
#
#
#  Above function named **correct_spelling** works as following:
#
#
# *   First checks if the word is already in our dataset that contains the correct spellings then it will return that the spelling is already spelled correctly.
# *   **suggestion** stores *level_one_edit* and further edits
# *   **best_guesses** stores the words after edits that are also present in our dataset.
# *   lasty, we return words that we stored in *best_guesses* along with its probability.

# %% [markdown]
# -\
# -\
# -\
# -\
# -\
# -

# %%
Input_Word = "mispelled"
guesses = correct_spelling(Input_Word, vocabs, word_probas)
print(guesses)
# Out:
# [('misspelled', 8.174287248132329e-07), ('dispelled', 8.174287248132329e-07)]
